# %% [markdown]
# # Python 3 working kernel

# %% [markdown]
# # Data exploration

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web # pip install pandas_datareader


style.use('ggplot')

start = dt.datetime(2018,4,24)
end = dt.datetime(2019,  4,24)
df = web.DataReader('AAPL','yahoo',  start,end)
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2018-04-23  166.919998  164.089996  166.830002  165.240005  36515500.0
# 2018-04-24  166.330002  161.220001  165.669998  162.940002  33692000.0
# 2018-04-25  165.419998  162.410004  162.619995  163.649994  28382100.0
# 2018-04-26  165.729996  163.369995  164.119995  164.220001  27963000.0
# 2018-04-27  164.330002  160.630005  164.000000  162.320007  35655800.0
#
#              Adj Close
# Date
# 2018-04-23  162.137238
# 2018-04-24  159.880402
# 2018-04-25  160.577057
# 2018-04-26  161.136368
# 2018-04-27  159.272049

# %%
df.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   191.921819  188.207786  190.050040  190.163320  3.212594e+07
# std     21.728724   21.454309   21.567157   21.575702  1.419415e+07
# min    145.720001  142.000000  143.979996  142.190002  1.251390e+07
# 25%    175.000000  172.350006  173.869995  174.240005  2.252550e+07
# 50%    190.160004  187.529999  189.009995  188.720001  2.838210e+07
# 75%    209.250000  206.089996  207.360001  207.529999  3.835890e+07
# max    233.470001  229.779999  230.779999  232.070007  9.624670e+07
#
#         Adj Close
# count  253.000000
# mean   188.167605
# std     21.190458
# min    141.039642
# 25%    172.830338
# 50%    187.062546
# 75%    205.748108
# max    229.392090

# %%
plt.plot(df.index, df['Adj Close'] )
plt.ylabel('Adj Close')
plt.title('AAPL Adj Close Apr 2018- Apr 2019')
plt.savefig('Fig_AAPL/AAPL_raw_data_snap_shot_fig.png')

# %%
df_AAPL =df

# %%
#df = pd.read_csv('../dataset/GOOG-year.csv')
#df.head()

# %%
start = dt.datetime(2018,4,24)
end = dt.datetime(2019,  4,24)
df = web.DataReader('GOOG','yahoo',  start,end)
df.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2018-04-23  1082.719971  1060.699951  1077.859985  1067.449951  2341300
# 2018-04-24  1057.000000  1010.590027  1052.000000  1019.979980  4760300
# 2018-04-25  1032.489990  1015.309998  1025.520020  1021.179993  2391100
# 2018-04-26  1047.979980  1018.190002  1029.510010  1040.040039  2079500
# 2018-04-27  1049.500000  1025.589966  1046.000000  1030.050049  1619800
#
#               Adj Close
# Date
# 2018-04-23  1067.449951
# 2018-04-24  1019.979980
# 2018-04-25  1021.179993
# 2018-04-26  1040.040039
# 2018-04-27  1030.050049

# %%
df.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count   253.000000   253.000000   253.000000   253.000000  2.530000e+02
# mean   1140.314657  1117.528862  1128.812510  1129.299879  1.588594e+06
# std      65.982735    70.334942    68.649881    68.736806  6.484036e+05
# min    1003.539978   970.109985   973.900024   976.219971  6.790000e+05
# 25%    1083.974976  1060.680054  1072.939941  1071.469971  1.199300e+06
# 50%    1132.170044  1111.010010  1123.140015  1121.280029  1.443200e+06
# 75%    1197.880005  1181.000000  1189.390015  1186.959961  1.848700e+06
# max    1273.890015  1255.000000  1271.000000  1268.329956  4.760300e+06
#
#          Adj Close
# count   253.000000
# mean   1129.299879
# std      68.736806
# min     976.219971
# 25%    1071.469971
# 50%    1121.280029
# 75%    1186.959961
# max    1268.329956

# %%
plt.plot(df.index, df['Adj Close'] )
plt.ylabel('Adj Close')
plt.title('GOOG Adj Close Apr 2018- Apr 2019')
plt.savefig('Fig_GOOG/GOOG_raw_data_snap_shot_fig.png')

# %%
df_GOOG =df

# %%
start = dt.datetime(2018,4,24)
end = dt.datetime(2019,  4,24)
df = web.DataReader('SPY','yahoo',  start,end)
df.head()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2018-04-23  267.890015  265.350006  267.260010  266.570007   65558000.0
# 2018-04-24  267.980011  261.279999  267.730011  262.980011  112885500.0
# 2018-04-25  264.130005  260.850006  262.910004  263.630005  103840900.0
# 2018-04-26  267.250000  264.290009  264.790009  266.309998   67731900.0
# 2018-04-27  267.339996  265.500000  267.000000  266.559998   57053600.0
#
#              Adj Close
# Date
# 2018-04-23  261.496857
# 2018-04-24  257.975189
# 2018-04-25  258.612793
# 2018-04-26  261.241821
# 2018-04-27  261.487030

# %%
df.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  253.000000  253.000000  253.000000  253.000000  2.530000e+02
# mean   276.915177  274.029525  275.594586  275.585692  8.578138e+07
# std     10.411602   11.546955   10.994446   10.955543  4.042467e+07
# min    240.839996  233.759995  235.970001  234.339996  3.565240e+07
# 25%    271.549988  267.829987  269.510010  270.059998  5.911460e+07
# 50%    277.959991  275.230011  276.769989  276.559998  7.296940e+07
# 75%    284.170013  281.769989  283.399994  283.339996  9.949500e+07
# max    293.940002  292.070007  293.089996  293.579987  2.748405e+08
#
#         Adj Close
# count  253.000000
# mean   272.747716
# std     10.950911
# min    233.312317
# 25%    266.406525
# 50%    273.144806
# 75%    280.890656
# max    292.880005

# %%
plt.plot(df.index, df['Adj Close'] )
plt.ylabel('Adj Close')
plt.title('SPY Adj Close Apr 2018- Apr 2019')
plt.savefig('Fig_SPY/SPY_raw_data_snap_shot_fig.png')

# %%
df_SPY = df

# %%
import matplotlib.pyplot as plt
plt.scatter(df_AAPL['Adj Close'],df_SPY['Adj Close'],  marker='+')
# s=80, c=z, marker=">")
plt.title('AAPL and SPY  relationship ')
plt.xlabel('AAPL')
plt.ylabel('SPY')
plt.savefig('Fig_Correlation/AAPL_SPY_Corr_fig.png')

# %%
import matplotlib.pyplot as plt
plt.scatter(df_GOOG['Adj Close'],df_SPY['Adj Close'],  marker='+')
# s=80, c=z, marker=">")
plt.title('GOOG and SPY  relationship ')
plt.xlabel('GOOG')
plt.ylabel('SPY')
plt.savefig('Fig_Correlation/GOOG_SPY_Corr_fig.png')

# %%
import matplotlib.pyplot as plt
plt.scatter(df_AAPL['Adj Close'],df_GOOG['Adj Close'],  marker='+')
# s=80, c=z, marker=">")
plt.title('AAPL and GOOG  relationship ')
plt.xlabel('AAPL')
plt.ylabel('GOOG')
plt.savefig('Fig_Correlation/AAPL_GOOG_Corr_fig.png')

# %%
start = dt.datetime(2018,4,24)
end = dt.datetime(2019,  4,24)
df = web.DataReader('GLD','yahoo',  start,end)
df.head()
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2018-04-23  125.760002  125.339996  125.620003  125.620003  6921500
# 2018-04-24  126.339996  125.669998  125.779999  126.230003  4733100
# 2018-04-25  125.510002  125.059998  125.230003  125.410004  5985700
# 2018-04-26  125.570000  124.690002  125.540001  124.970001  7517100
# 2018-04-27  125.620003  125.169998  125.199997  125.500000  5654000
#
#              Adj Close
# Date
# 2018-04-23  125.620003
# 2018-04-24  126.230003
# 2018-04-25  125.410004
# 2018-04-26  124.970001
# 2018-04-27  125.500000

# %%
plt.plot(df.index, df['Adj Close'] )
plt.ylabel('Adj Close')
plt.title('GLD Adj Close Apr 2018- Apr 2019')
plt.savefig('Fig_GLD/GLD_raw_data_snap_shot_fig.png')

# %%
df_GLD = df

# %%
plt.scatter(df_AAPL['Adj Close'],df_GLD['Adj Close'],  marker='+')
# s=80, c=z, marker=">")
plt.title('AAPL and GLD  relationship ')
plt.xlabel('AAPL')
plt.ylabel('GLD')
plt.savefig('Fig_Correlation/AAPL_GLD_Corr_fig.png')

# %%
plt.scatter(df_AAPL['Adj Close'],df_AAPL['Volume'],  marker='+')
# s=80, c=z, marker=">")
plt.title('AAPL Adj and Volume  relationship ')
plt.xlabel('AAPL Adj Close')
plt.ylabel('Volume')
plt.savefig('Fig_Correlation/AAPL_AdjClose_Volume_Corr_fig.png')

# %%
corr_matrix=df_GLD.corr()
coef=corr_matrix["Adj Close"].sort_values(ascending=False)
pos_corr=coef[coef>0]
pos_corr
# Out:
# Adj Close    1.000000
# Close        1.000000
# Low          0.998079
# High         0.997614
# Open         0.994879
# Name: Adj Close, dtype: float64

# %%
coef
# Out:
# Adj Close    1.000000
# Close        1.000000
# Low          0.998079
# High         0.997614
# Open         0.994879
# Volume      -0.008040
# Name: Adj Close, dtype: float64

# %%
coef.index
# Out:
# Index(['Adj Close', 'Close', 'Low', 'High', 'Open', 'Volume'], dtype='object')

# %%
importances = coef
n=6
pd.Series(importances, index=coef.index).sort_values()[-n:].plot(kind='barh');
plt.xlabel('correlation coefficient ')
plt.title('Correlation between AAPL data columns')
plt.savefig('Fig_Correlation/AAPL_corr_chart.png')

# %%
#f_all =

# %% [markdown]
# ## Understand the abcd policy

# %%
def abcd(trend, skip_loop = 4, ma = 7):
    ma = pd.Series(trend).rolling(ma).mean().values
    x = []
    for a in range(ma.shape[0]):
        for b in range(a, ma.shape[0], skip_loop):
            for c in range(b, ma.shape[0], skip_loop):
                for d in range(c, ma.shape[0], skip_loop):
                    if ma[b] > ma[a] and \
                    (ma[c] < ma[b] and ma[c] > ma[a]) \
                    and ma[d] > ma[b]:
                        x.append([a,b,c,d])
    x_np = np.array(x)
    ac = x_np[:,0].tolist() + x_np[:,2].tolist()
    bd = x_np[:,1].tolist() + x_np[:,3].tolist()
    ac_set = set(ac)
    bd_set = set(bd)
    signal = np.zeros(len(trend))
    buy = list(ac_set - bd_set)
    sell = list(list(bd_set - ac_set))
    signal[buy] = 1.0
    signal[sell] = -1.0
    return signal

# %%
# %%time
signal = abcd(df['Close'])
# Out:
# CPU times: user 1.34 s, sys: 6.5 ms, total: 1.35 s
# Wall time: 1.35 s

# %%
trend = df_AAPL['Adj Close']
ma =7 
skip_loop = 4
ma = pd.Series(trend).rolling(ma).mean().values
x = []
for a in range(ma.shape[0]):
    for b in range(a, ma.shape[0], skip_loop):
        for c in range(b, ma.shape[0], skip_loop):
            for d in range(c, ma.shape[0], skip_loop):
                if ma[b] > ma[a] and \
                (ma[c] < ma[b] and ma[c] > ma[a]) \
                and ma[d] > ma[b]:
                    x.append([a,b,c,d])
x_np = np.array(x)
ac = x_np[:,0].tolist() + x_np[:,2].tolist()
bd = x_np[:,1].tolist() + x_np[:,3].tolist()
ac_set = set(ac)
bd_set = set(bd)
signal = np.zeros(len(trend))
buy = list(ac_set - bd_set)
sell = list(list(bd_set - ac_set))
signal[buy] = 1.0
signal[sell] = -1.0

# %%
len(ma)
# Out:
# 253

# %%
x_np
# Out:
# array([[  6,  10, 166, 214],
#        [  6,  10, 166, 218],
#        [  6,  10, 166, 222],
#        ...,
#        [212, 216, 220, 244],
#        [212, 216, 220, 248],
#        [212, 216, 220, 252]])

# %%
a,b,c,d=[  6,  10, 166, 214]
plt.plot(np.arange(0,d+1,1),ma[0:d+1:1], '-')

plt.plot(np.arange(0,d+1,1),ma[0:d+1:1], '^', markersize=10, color='g', label = 'a, c', markevery =[  a,c])
#plt.plot(np.arange(1,d+1,1),ma[1:d+1:1], '^', markersize=10, color='c', label = 'c', markevery =[  c])
plt.plot(np.arange(0,d+1,1),ma[0:d+1:1], 'v', markersize=10, color='r', label = 'b d ', markevery =[ b,d])
#plt.plot(np.arange(1,d+1,1),ma[1:d+1:1], 'v', markersize=10, color='r', label = 'selling signal d', markevery =[ d])
plt.xlabel('day')
plt.ylabel('ma[Adj Close]')
plt.title('abcd pattern: a and c are in green and b and d are in red')
plt.legend()
plt.savefig('Fig_AAPL/AAPL_abcd_chart.png')

# %%
np.asarray(df['Close'])
# Out:
# array([125.62000275, 126.23000336, 125.41000366, 124.97000122,
#        125.5       , 124.58999634, 123.70999908, 123.65000153,
#        124.27999878, 124.54000092, 124.56999969, 124.58999634,
#        124.33000183, 125.18000031, 125.        , 124.48999786,
#        122.48000336, 122.29000092, 122.36000061, 122.41000366,
#        122.48000336, 122.41000366, 122.54000092, 123.58999634,
#        123.20999908, 123.19000244, 123.37000275, 123.09999847,
#        122.48999786, 122.37000275, 122.84999847, 122.91999817,
#        122.86000061, 123.01000214, 123.23000336, 122.81999969,
#        123.19000244, 123.37999725, 121.33999634, 121.11000061,
#        120.80000305, 120.26000214, 120.05000305, 120.33999634,
#        119.88999939, 119.26000214, 118.58000183, 118.22000122,
#        118.65000153, 117.45999908, 118.65000153, 119.05000305,
#        118.86000061, 119.15000153, 118.93000031, 117.63999939,
#        118.12999725, 117.61000061, 117.55000305, 116.27999878,
# ...

# %%
df2=pd.DataFrame({'signal':np.asarray(signal),'Close': np.asarray(df['Close'])})

# %%
df2.head()
# Out:
#    signal       Close
# 0     0.0  125.620003
# 1     0.0  126.230003
# 2     0.0  125.410004
# 3     0.0  124.970001
# 4     0.0  125.500000

# %%
def buy_stock(
    real_movement,
    signal,
    initial_money = 10000,
    max_buy = 1,
    max_sell = 1,
):
    """
    real_movement = actual movement in the real world
    delay = how much interval you want to delay to change our decision from buy to sell, vice versa
    initial_state = 1 is buy, 0 is sell
    initial_money = 10000, ignore what kind of currency
    max_buy = max quantity for share to buy
    max_sell = max quantity for share to sell
    """
    starting_money = initial_money
    states_sell = []
    states_buy = []
    states_money = []
    current_inventory = 0
    
    def buy(i, initial_money, current_inventory):
        shares = initial_money // real_movement[i]
        if shares < 1:
            print(
                'day %d: total balances %f, not enough money to buy a unit price %f'
                % (i, initial_money, real_movement[i])
            )
        else:
            if shares > max_buy:
                buy_units = max_buy
            else:
                buy_units = shares
            initial_money -= buy_units * real_movement[i]
            current_inventory += buy_units
            print(
                'day %d: buy %d units at price %f, total balance %f'
                % (i, buy_units, buy_units * real_movement[i], initial_money)
            )
            states_buy.append(0)
        return initial_money, current_inventory
    
    for i in range(real_movement.shape[0]):
        state = signal[i]
        if state == 1:
            initial_money, current_inventory = buy(
                i, initial_money, current_inventory
            )
            states_buy.append(i)
        elif state == -1:
            if current_inventory == 0:
                    print('day %d: cannot sell anything, inventory 0' % (i))
            else:
                if current_inventory > max_sell:
                    sell_units = max_sell
                else:
                    sell_units = current_inventory
                current_inventory -= sell_units
                total_sell = sell_units * real_movement[i]
                initial_money += total_sell
                try:
                    invest = (
                        (real_movement[i] - real_movement[states_buy[-1]])
                        / real_movement[states_buy[-1]]
                    ) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell %d units at price %f, investment %f %%, total balance %f,'
                    % (i, sell_units, total_sell, invest, initial_money)
                )
            states_sell.append(i)
        states_money.append(initial_money)
            
    #invest = ((initial_money - starting_money) / starting_money) * 100
    #total_gains = initial_money - starting_money
    invest = ((initial_money +current_inventory*real_movement[i]- starting_money) / starting_money) * 100
    total_gains = initial_money +current_inventory*real_movement[i]- starting_money

    return states_buy, states_sell, total_gains, invest, states_money

# %%
states_buy, states_sell, total_gains, invest, states_money = buy_stock(df.Close, signal)
# Out:
# day 6: buy 1 units at price 123.709999, total balance 9876.290001
# day 7: buy 1 units at price 123.650002, total balance 9752.639999
# day 8: buy 1 units at price 124.279999, total balance 9628.360001
# day 9: buy 1 units at price 124.540001, total balance 9503.820000
# day 94, sell 1 units at price 113.320000, investment -9.009155 %, total balance 9617.139999,
# day 95, sell 1 units at price 113.540001, investment -8.832504 %, total balance 9730.680000,
# day 96, sell 1 units at price 113.230003, investment -9.081418 %, total balance 9843.910004,
# day 97, sell 1 units at price 113.150002, investment -9.145655 %, total balance 9957.060005,
# day 98: cannot sell anything, inventory 0
# day 113: cannot sell anything, inventory 0
# day 114: cannot sell anything, inventory 0
# day 115: cannot sell anything, inventory 0
# day 116: cannot sell anything, inventory 0
# day 117: cannot sell anything, inventory 0
# day 118: cannot sell anything, inventory 0
# ...

# %%
close = df['Close']
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='k', lw=2.)
plt.plot(close, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(states_money, color='k', lw=2.)
plt.plot(states_money, '^', markersize=10, color='g', label = 'buying signal', markevery = states_buy)
plt.plot(states_money, 'v', markersize=10, color='r', label = 'selling signal', markevery = states_sell)
plt.legend()
plt.show()
